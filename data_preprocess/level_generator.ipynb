# %%
"""Алгоритм парсит название папок в входной папке """

from pathlib import Path
import pandas as pd

MODEL_DIR = str(Path('../data/models/'))

from os import listdir
from os.path import isdir, join

model_dirs = [dir_ for dir_ in listdir(MODEL_DIR) if isdir(join(MODEL_DIR, dir_)) and dir_.startswith('model')]

# %%
model_dirs
# Out:
# ['model_1_60_7', 'model_1_90_15', 'model_1_30_4']

# %%
from collections import defaultdict
import re
from envparse import env
import ssl
import pymongo as pym

# %%
import yfinance as yf
import pandas as pd
from gdeltdoc import Filters, GdeltDoc
from datetime import timedelta
from pathlib import Path
import time


def get_shift_percentage(numerator: pd.Series,
                         denominator: pd.Series) -> pd.Series:
    """
    На сколько процентов изменилась переменная numerator
    относительно текущего denominator
    """
    return numerator / denominator * 100


def get_shift_digit(s: pd.Series) -> pd.Series:
    """
    Возвращает колонку с изменениями значений
    Для вызова этой функции необходимо очистить колонки Close от NaN
    """
    assert not s.isna().any(), "Необходимо очистить колонку от NaN"

    return (s.shift(-1) - s).shift(1)


def get_data_yfinance(quotation: str,
                      start_date: str,
                      end_date: str,
                      interval='1d') -> pd.DataFrame:
    """
    Взять данные с yahoo finance

    params:
        quotation: название котировки, данные для которой хотим получить
        start_date, end_date - интервал, формат "год-месяц-день"
        interval - периодичность, формат "(номер)(первая буква слова (d, m, y))"
    returns:
        DataFrame формата "Тикет, Время, 6 видов цен"
    """

    df_res = yf.download(tickers=quotation,
                         start=start_date,
                         end=end_date,
                         interval=interval)
    df_res.loc[:, 'Ticker'] = quotation
    df_res = df_res.groupby(pd.Grouper(level="Date",
                                       freq=interval.upper())).mean()
    # Приводим время к одному виду для слияния
    df_res.index = pd.to_datetime(df_res.index).tz_localize('Etc/UCT')
    return df_res


def get_data_gdelt(quotation: str,
                   keywords: list,
                   start_date: str,
                   end_date: str,
                   interval="1d",
                   num_records=250,
                   repeats=3) -> pd.DataFrame:
    """
    Взять данные с gdelt

    params:
        quotation - имя ценной бумаги
        keywords - из графа знаний по ключевому слову
        start_date, end_date - интервал, формат "год-месяц-день"
        (опционально) interval - периодичность, формат "(номер)(первая буква слова (d, m, y))"
        (не реализована) (опционально) num_records - сколько максимум записей взять за промежуток
        (не реализовано) (опционально) repeats - сколько раз должно повториться ключевое слово в статье
    returns:
        DataFrame формата "Datetime (индекс), Ticker,
        [Average_Tone, Article_Count, Volume_Intensity]_[std, mean, sum, min, max]
    """

    # Колонки в полученных DataFrames
    col_names = ['Average_Tone', 'Article_Count', 'Volume_Intensity']

    # Что будем искать для данных ключевых слов
    # Тон статей, их количество и их кол-во в отношении ко всем остальным на gdelt
    match_list = ["timelinetone", "timelinevolraw", "timelinevol"]
    match_dict = dict(zip(match_list, col_names))

    df_res = None
    for keyword in keywords:
        try:
            gd_filter = Filters(start_date=start_date,
                                end_date=end_date,
                                keyword=keyword)

            for feature_name in match_list:
                gd = GdeltDoc()
                timeline_data = gd.timeline_search(feature_name, gd_filter)
                time.sleep(5)
                timeline_data = timeline_data.fillna(0)
                timeline_data = timeline_data.groupby(
                    pd.Grouper(key="datetime", freq=interval.upper()))

                if feature_name in ['timelinetone']:
                    timeline_data = timeline_data.mean()
                else:
                    timeline_data = timeline_data.sum()

                if df_res is None:
                    # Выровняем индексы, чтобы при копировании не выдавалось NaN
                    df_res = pd.DataFrame(index=timeline_data.index)

                col_name = match_dict[feature_name]
                df_res[f"{keyword}_{feature_name}_{col_name}"] = timeline_data[
                    col_name.replace('_', ' ')].values
        except Exception as e:
            print(f'invalid keyword: {keyword}')

    return df_res


def set_statistic_columns(df_dub: pd.DataFrame) -> pd.DataFrame:
    """После использования этой функции желательно удалить df_dub"""

    # Колонки в полученных DataFrames
    col_names = ['Average_Tone', 'Article_Count', 'Volume_Intensity']

    df_res = pd.DataFrame(index=df_dub.index)

    # Нужно создать колонки со средним, средним отклонением, минимумом и максимумом для каждой фичи
    # Сначала сформируем список датафреймов, которые нам нужно достать для каждой колонки
    for pattern in col_names:
        pattern_list = list()
        for col in df_dub.columns:
            if pattern in col:
                pattern_list.append(col)

        # Теперь для pattern у нас есть список
        df_res[f'{pattern}_min'] = df_dub[pattern_list].min(axis=1,
                                                            skipna=True)
        df_res[f'{pattern}_max'] = df_dub[pattern_list].max(axis=1,
                                                            skipna=True)
        df_res[f'{pattern}_mean'] = df_dub[pattern_list].mean(axis=1,
                                                              skipna=True)
        df_res[f'{pattern}_std'] = df_dub[pattern_list].std(axis=1,
                                                            skipna=True)
        df_res[f'{pattern}_sum'] = df_dub[pattern_list].sum(axis=1,
                                                            skipna=True)

    return df_res


def set_column_ticker(df: pd.DataFrame, quotation: str) -> None:
    # Добавим название ценной бумаги в таблицу
    df.loc[:, 'Ticker'] = quotation


def get_nan_chain(nan_series: pd.Series) -> list:
    """Берет цепочки NaN из фрейма"""
    res = []
    day = timedelta(days=1)
    along = list(nan_series[nan_series].index)

    prev_day = along[0]
    chain = [prev_day]
    for cur_day in along[1:]:
        if cur_day - prev_day == day:
            chain.append(cur_day)
        else:
            res.append(chain)
            chain = [cur_day]

        prev_day = cur_day

    return res


def set_cumulative_effect(df: pd.DataFrame, chains: list) -> None:
    """Меняет переданный датафрейм, не убирая NaN"""
    day = timedelta(days=1)

    for chain in chains:
        buffer = None
        for date in chain:
            if buffer is None:
                buffer = df.loc[date]
            else:
                buffer += df.loc[date]

        cumulative_day = chain[-1] + day
        # Берем все дни из цепочки, в строке будет среднее арифметическое этих дней
        df.loc[cumulative_day] = (df.loc[cumulative_day] +
                                  buffer) / (len(chain) + 1)


def get_dataframe_v2(**kwargs) -> pd.DataFrame:
    """
    Получить полный датафрейм с кумулятивностью и дополнительными фичами
    Пример использования: d = get_dataframe(quotation='NVDA',
                                            keywords=['nvidia', 'geforce', 'geforce rtx', 'geForce now',
                                            'nvidia rtx', 'nvidia shield', 'nvidia dgx'],
                                            start_date="2020-01-01",
                                            end_date="2020-12-31")

    params:
        quotation - имя ценной бумаги
        keywords - из графа знаний по ключевому слову
        start_date, end_date - интервал, формат "год-месяц-день"
        (опционально) interval - периодичность, формат "(номер)(первая буква слова (d, m, y))"
        (не реализована) (опционально) num_records - сколько максимум записей взять за промежуток
        (не реализовано) (опционально) repeats - сколько раз должно повториться ключевое слово в статье
    returns:
        DataFrame формата "Datetime (индекс), Ticker,
        [Average_Tone, Article_Count, Volume_Intensity]_[std, mean, sum, min, max], - из новостей
        Open, High, Low, Close, Adj Close, Volume - из финансов
    """

    gdelt_data = get_data_gdelt(**kwargs)
    yfinance_data = get_data_yfinance(
        quotation=kwargs['quotation'],
        start_date=kwargs['start_date'],
        end_date=kwargs['end_date'],
        interval="1d" if not kwargs.get('interval') else kwargs['interval'])

    row_is_nan = yfinance_data['Close'].isna()
    yfinance_data.dropna(inplace=True)
    set_cumulative_effect(gdelt_data, get_nan_chain(row_is_nan))
    gdelt_data.drop(row_is_nan[row_is_nan].index, inplace=True)
    gdelt_data = set_statistic_columns(gdelt_data)

    set_column_ticker(gdelt_data, quotation=kwargs['quotation'])
    set_column_ticker(yfinance_data, quotation=kwargs['quotation'])
    yfinance_data['Price Change'] = get_shift_digit(
        yfinance_data['Close'].dropna())
    yfinance_data['Percentage Change'] = get_shift_percentage(
        yfinance_data['Price Change'], yfinance_data['Close'])
    gdelt_data = gdelt_data.iloc[1:-1].reset_index()
    yfinance_data = yfinance_data.reset_index()

    return gdelt_data, yfinance_data

# %%
d, y = get_dataframe_v2(quotation='NVDA',
                                            keywords=['nvidia', 'geforce', 'geforce rtx', 'geForce now',
                                            'nvidia rtx', 'nvidia shield', 'nvidia dgx'],
                                            start_date="2020-01-01",
                                            end_date="2020-12-31")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-153-d0eddddd8590> in <module>
# ----> 1 d, y = get_dataframe_v2(quotation='NVDA',
#       2                                             keywords=['nvidia', 'geforce', 'geforce rtx', 'geForce now',
#       3                                             'nvidia rtx', 'nvidia shield', 'nvidia dgx'],
#       4                                             start_date="2020-01-01",
#       5                                             end_date="2020-12-31")
#
# <ipython-input-152-d2e7b279b99a> in get_dataframe_v2(**kwargs)
#     212     """
#     213
# --> 214     gdelt_data = get_data_gdelt(**kwargs)
#     215     yfinance_data = get_data_yfinance(
#     216         quotation=kwargs['quotation'],
#
# <ipython-input-152-d2e7b279b99a> in get_data_gdelt(quotation, keywords, start_date, end_date, interval, num_records, repeats)
#      93                 gd = GdeltDoc()
#      94                 timeline_data = gd.timeline_search(feature_name, gd_filter)
# ---> 95                 time.sleep(5)
#      96                 timeline_data = timeline_data.fillna(0)
#      97                 timeline_data = timeline_data.groupby(
#
# KeyboardInterrupt:

# %%
d

# %%
MODEL_DIR + '/' + 'model_1_120_30' + '/test_data.csv'
# Out:
# 'models/model_1_120_30/test_data.csv'

# %%
frames['model_1_120_30'][frames['model_1_120_30']['Ticker'] == 'MMM']
# Out:
# Empty DataFrame
# Columns: [index, Ticker, Adj Close_percent_pr-120, Adj Close_percent_pr-119, Adj Close_percent_pr-118, Adj Close_percent_pr-117, Adj Close_percent_pr-116, Adj Close_percent_pr-115, Adj Close_percent_pr-114, Adj Close_percent_pr-113, Adj Close_percent_pr-112, Adj Close_percent_pr-111, Adj Close_percent_pr-110, Adj Close_percent_pr-109, Adj Close_percent_pr-108, Adj Close_percent_pr-107, Adj Close_percent_pr-106, Adj Close_percent_pr-105, Adj Close_percent_pr-104, Adj Close_percent_pr-103, Adj Close_percent_pr-102, Adj Close_percent_pr-101, Adj Close_percent_pr-100, Adj Close_percent_pr-99, Adj Close_percent_pr-98, Adj Close_percent_pr-97, Adj Close_percent_pr-96, Adj Close_percent_pr-95, Adj Close_percent_pr-94, Adj Close_percent_pr-93, Adj Close_percent_pr-92, Adj Close_percent_pr-91, Adj Close_percent_pr-90, Adj Close_percent_pr-89, Adj Close_percent_pr-88, Adj Close_percent_pr-87, Adj Close_percent_pr-86, Adj Close_percent_pr-85, Adj Close_percent_pr-84, Adj Close_percent_pr-83, Adj Close_percent_pr-82, Adj Close_percent_pr-81, Adj Close_percent_pr-80, Adj Close_percent_pr-79, Adj Close_percent_pr-78, Adj Close_percent_pr-77, Adj Close_percent_pr-76, Adj Close_percent_pr-75, Adj Close_percent_pr-74, Adj Close_percent_pr-73, Adj Close_percent_pr-72, Adj Close_percent_pr-71, Adj Close_percent_pr-70, Adj Close_percent_pr-69, Adj Close_percent_pr-68, Adj Close_percent_pr-67, Adj Close_percent_pr-66, Adj Close_percent_pr-65, Adj Close_percent_pr-64, Adj Close_percent_pr-63, Adj Close_percent_pr-62, Adj Close_percent_pr-61, Adj Close_percent_pr-60, Adj Close_percent_pr-59, Adj Close_percent_pr-58, Adj Close_percent_pr-57, Adj Close_percent_pr-56, Adj Close_percent_pr-55, Adj Close_percent_pr-54, Adj Close_percent_pr-53, Adj Close_percent_pr-52, Adj Close_percent_pr-51, Adj Close_percent_pr-50, Adj Close_percent_pr-49, Adj Close_percent_pr-48, Adj Close_percent_pr-47, Adj Close_percent_pr-46, Adj Close_percent_pr-45, Adj Close_percent_pr-44, Adj Close_percent_pr-43, Adj Close_percent_pr-42, Adj Close_percent_pr-41, Adj Close_percent_pr-40, Adj Close_percent_pr-39, Adj Close_percent_pr-38, Adj Close_percent_pr-37, Adj Close_percent_pr-36, Adj Close_percent_pr-35, Adj Close_percent_pr-34, Adj Close_percent_pr-33, Adj Close_percent_pr-32, Adj Close_percent_pr-31, Adj Close_percent_pr-30, Adj Close_percent_pr-29, Adj Close_percent_pr-28, Adj Close_percent_pr-27, Adj Close_percent_pr-26, Adj Close_percent_pr-25, Adj Close_percent_pr-24, Adj Close_percent_pr-23, ...]
# Index: []
#
# [0 rows x 243 columns]

# %%
def get_frames_for_company(company: str, model_dirs, number_of_samples) -> dict:
    #rand_tickers = [i for i in range(10)]
    df_test_10 = {}
    for model in model_dirs:
        df_test = pd.read_csv(MODEL_DIR + '/' + model + '/test_data.csv', nrows=100)
        df_test[model] = df_test[df_test['Ticker'] == company].head(number_of_samples)
    return df_test

# %%
df_test = pd.read_csv(MODEL_DIR + '/' + 'model_1_120_30' + '/test_data.csv', nrows=100)
# df_test['model_1_120_30'] = df_test[df_test['Ticker'] == 'ABT'].head(10)
# df_test['model_1_120_30']
df_test[df_test['Ticker'] == 'ABT'].head(10)

# %%
test = {}
test['MMM'] = get_frames_for_company('MMM', model_dirs, 10)
#for company in tickets:
    #test[company] = get_frames_for_company(company, model_dirs, 10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\Programs\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'model_1_120_30'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1052         try:
# -> 1053             loc = self.items.get_loc(item)
#    1054         except KeyError:
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'model_1_120_30'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-a666967ad7e0> in <module>
#       1 test = {}
# ----> 2 test['MMM'] = get_frames_for_company('MMM', model_dirs, 10)
#       3 #for company in tickets:
#       4     #test[company] = get_frames_for_company(company, model_dirs, 10)
#
# <ipython-input-9-00dc6f79a4e4> in get_frames_for_company(company, model_dirs, number_of_samples)
#       4     for model in model_dirs:
#       5         df_test = pd.read_csv(MODEL_DIR + '/' + model + '/test_data.csv', nrows=100)
# ----> 6         df_test[model] = df_test[df_test['Ticker'] == company].head(number_of_samples)
#       7     return df_test
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1054         except KeyError:
#    1055             # This item wasn't present, just insert at end
# -> 1056             self.insert(len(self.items), item, value)
#    1057             return
#    1058
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1156
#    1157         block = make_block(values=value, ndim=self.ndim,
# -> 1158                            placement=slice(loc, loc + 1))
#    1159
#    1160         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2629
#    2630         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2631                                           placement=placement)
#    2632
#    2633     @property
#
# E:\Programs\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#      85             raise ValueError(
#      86                 'Wrong number of items passed {val}, placement implies '
# ---> 87                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#      88
#      89     def _check_ndim(self, values, ndim):
#
# ValueError: Wrong number of items passed 243, placement implies 1

# %%
days_back
# Out:
# {'model_1_120_30': '120',
#  'model_2_120_30': '120',
#  'model_3_120_30': '120',
#  'model_4_120_30': '120',
#  'model_5_120_30': '120'}

# %%
frames = get_frames_for_company('ABT', days_back)

# %%
frames['model_1_120_30']
# Out:
#                         index Ticker  Adj Close_percent_pr-120  \
# 2   2017-01-31 00:00:00+00:00    ABT                  0.000000
# 5   2017-02-01 00:00:00+00:00    ABT                 -1.662297
# 8   2017-02-02 00:00:00+00:00    ABT                  0.711743
# 11  2017-02-03 00:00:00+00:00    ABT                 -0.435163
# 14  2017-02-07 00:00:00+00:00    ABT                 -2.097900
# 17  2017-02-08 00:00:00+00:00    ABT                 -3.928568
# 20  2017-02-09 00:00:00+00:00    ABT                 -1.672865
# 23  2017-02-10 00:00:00+00:00    ABT                  0.611002
# 26  2017-02-14 00:00:00+00:00    ABT                 -1.113357
# 29  2017-02-15 00:00:00+00:00    ABT                 -0.204713
#
#     Adj Close_percent_pr-119  Adj Close_percent_pr-118  \
# 2                   0.820623                 -0.857629
# 5                  -0.069771                 -1.297582
# 8                  -1.309058                  3.593353
# 11                  0.230033                 -1.734627
# 14                  2.065686                  3.883499
# 17                  0.599664                 -1.614267
# 20                  0.183418                  1.208966
# 23                  0.566457                  0.167935
# 26                 -1.298980                 -1.676457
# 29                 -0.128111                 -2.728046
#
#     Adj Close_percent_pr-117  Adj Close_percent_pr-116  \
# 2                   0.863807                  0.758402
# 5                   2.720423                  0.031371
# 8                   1.350002                 -0.218049
# 11                  0.134066                 -3.610268
# 14                 -0.876349                  0.228984
# 17                  0.515727                  1.158618
# 20                 -0.342282                 -0.323311
# 23                 -0.883209                 -0.454098
# 26                  0.148495                 -0.374706
# 29                 -0.074378                 -0.623362
#
#     Adj Close_percent_pr-115  Adj Close_percent_pr-114  \
# 2                  -0.803525                 -1.499063
# 5                   0.531313                  1.139234
# 8                  -4.158486                  0.052169
# 11                 -0.864221                  0.921272
# 14                  0.988592                 -0.292812
# 17                  2.936723                  1.010530
# 20                 -0.657779                 -0.068964
# 23                 -0.935815                 -0.388103
# 26                 -0.329741                 -0.372284
# 29                  0.654301                  1.445746
#
#     Adj Close_percent_pr-113  ...  Average_Tone_mean_pr-9  \
# 2                   1.552487  ...                0.230000
# 5                  -0.079083  ...               -0.386700
# 8                   1.803700  ...               -0.405850
# 11                  2.136543  ...               -0.472375
# 14                 -0.178575  ...                0.004875
# 17                 -0.460015  ...               -0.540950
# 20                  0.333765  ...               -0.623075
# 23                 -0.562951  ...                0.008875
# 26                  0.283074  ...                0.173225
# 29                  1.479367  ...               -0.697100
#
#     Average_Tone_mean_pr-8  Average_Tone_mean_pr-7  Average_Tone_mean_pr-6  \
# 2                  0.45690                  0.2107                 0.37078
# 5                  0.20980                  0.0000                 0.31314
# 8                 -0.04736                  0.2286                 0.33072
# 11                 0.19392                  1.4448                 0.28566
# 14                 0.33830                  1.5370                 0.45206
# 17                -0.53000                 -1.0104                 0.42930
# 20                -0.16712                 -0.3559                 0.32218
# 23                -0.32020                  0.6155                 0.41174
# 26                -0.28010                 -0.9485                 0.73460
# 29                 0.44174                  0.5026                 0.29106
#
#     Average_Tone_mean_pr-5  Average_Tone_mean_pr-4  Average_Tone_mean_pr-3  \
# 2                  0.43578                 0.88942                 0.77116
# 5                 -0.43282                 0.90852                 0.73446
# 8                  0.48600                 0.47936                 0.70930
# 11                -0.22208                 0.85198                 0.70956
# 14                -0.34248                 0.36762                 0.31604
# 17                 0.23568                 0.82922                 0.31474
# 20                 0.36634                 0.64840                 0.27270
# 23                 0.36232                 1.32636                 0.09094
# 26                 0.06610                 1.73326                 0.04716
# 29                 0.50700                 1.15724                 0.48600
#
#     Average_Tone_mean_pr-2  Average_Tone_mean_pr-1  target
# 2                 0.639900                 0.28486       1
# 5                -0.253900                 0.79866       1
# 8                 0.451050                -0.00910       1
# 11                1.239925                 0.49034       1
# 14                0.115750                 0.00000       1
# 17               -0.627950                 0.08196       1
# 20                0.894775                 0.65572       1
# 23               -0.783650                 0.55556       1
# 26               -1.989150                 0.57692       1
# 29               -1.922875                 0.27650       1
#
# [10 rows x 243 columns]

# %%
"""Группируем папки  по days_back, days_forward, сохраняем название папок"""

from collections import defaultdict
import re

# pattern = re.compile('model_(\d+)_(\d+)_(\d)')
# d = defaultdict(list)
# for item in model_dirs:
#     i, db, df = pattern.match(item).groups()
#     d[(db, df)] += [item]

db = {model : model.split('_')[2] for model in model_dirs}
df = {model : model.split('_')[3] for model in model_dirs}

# %%
from catboost import CatBoostClassifier, Pool

def predict_for_model(path_to_model, test, cat_features):
    
    model = CatBoostClassifier(Pool(test, cat_features=cat_features))
    model.load_model(path_to_model, format='cbm')
    
    prediction = model.predict(test)
    
    return prediction

# %%
from gdeltdoc import GdeltDoc, Filters, near, repeat
from datetime import datetime, timedelta

def set_filters(from_date, days_back, keywords):
    
    delta = timedelta(days=int(days_back))
    date = datetime.strptime(from_date, "%Y-%m-%d")
    end_date = date + delta
    end_date = end_date.strftime("%Y-%m-%d")
    
    f = Filters(
        start_date = from_date,
        end_date = end_date,
        num_records = 250,
        keyword = keywords,
        domain = "finance.yahoo.com",
        country = ["UK", "US"],
        theme = "ECON_STOCKMARKET",
#         near = near(3, keywords, "company"),
        #repeat = repeat(5, "planet")
    )
    
    return f

# %%
def connect_to_mongodb():
    env.read_envfile()
    url = env("URL")
    ssl_ca_certs = str(Path('../additional/YandexInternalRootCA.crt'))
    con = pym.MongoClient(url,
                           ssl_ca_certs=ssl_ca_certs,
                           ssl_cert_reqs=ssl.CERT_REQUIRED)
    return con.get_database('stock-news-backend')

# %%
gd = GdeltDoc()
f = set_filters('2019-01-01', 30, ['Microsoft', 'Bill Gates'])

# %%
# Get a timeline of the number of articles matching the filters
timeline = gd.timeline_search("timelinetone", f)
timeline['datetime']
# Out:
# 0    2018-12-02 00:00:00+00:00
# 1    2018-12-03 00:00:00+00:00
# 2    2018-12-04 00:00:00+00:00
# 3    2018-12-05 00:00:00+00:00
# 4    2018-12-06 00:00:00+00:00
# 5    2018-12-07 00:00:00+00:00
# 6    2018-12-08 00:00:00+00:00
# 7    2018-12-09 00:00:00+00:00
# 8    2018-12-10 00:00:00+00:00
# 9    2018-12-11 00:00:00+00:00
# 10   2018-12-12 00:00:00+00:00
# 11   2018-12-13 00:00:00+00:00
# 12   2018-12-14 00:00:00+00:00
# 13   2018-12-15 00:00:00+00:00
# 14   2018-12-16 00:00:00+00:00
# 15   2018-12-17 00:00:00+00:00
# 16   2018-12-18 00:00:00+00:00
# 17   2018-12-19 00:00:00+00:00
# 18   2018-12-20 00:00:00+00:00
# 19   2018-12-21 00:00:00+00:00
# 20   2018-12-22 00:00:00+00:00
# 21   2018-12-23 00:00:00+00:00
# 22   2018-12-24 00:00:00+00:00
# 23   2018-12-25 00:00:00+00:00
# 24   2018-12-26 00:00:00+00:00
# 25   2018-12-27 00:00:00+00:00
# 26   2018-12-28 00:00:00+00:00
# 27   2018-12-29 00:00:00+00:00
# 28   2018-12-30 00:00:00+00:00
# 29   2018-12-31 00:00:00+00:00
# 30   2019-01-01 00:00:00+00:00
# Name: datetime, dtype: datetime64[ns, UTC]

# %%
def get_important_days(timeline, number_of_days):
    
    indexes = timeline['Volume Intensity'].values.argsort()[-number_of_days:][::-1]
    result = list(map(str, timeline['datetime'][indexes]))
    result = [result[i].split(' ')[0] for i in range(len(result))]
    
    return result

# %%
import random

def get_important_news(articles, important_day, keywords, number_of_news):
    
    articles = articles[articles['language'] == 'English']
    result = []
    for _ in range(number_of_news):
        index = random.randint(0, len(list(articles['title']))-1)
        result.append(list(articles['title'])[index])
    return result

# %%
important_days = get_important_days(timeline, 3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/comptech/stock-news/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Volume Intensity'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-199-58e5a3d3afd4> in <module>
# ----> 1 important_days = get_important_days(timeline, 3)
#
# <ipython-input-196-31498e35aa60> in get_important_days(timeline, number_of_days)
#       1 def get_important_days(timeline, number_of_days):
#       2
# ----> 3     indexes = timeline['Volume Intensity'].values.argsort()[-number_of_days:][::-1]
#       4     result = list(map(str, timeline['datetime'][important_days]))
#       5     result = [result[i].split(' ')[0] for i in range(len(result))]
#
# ~/Desktop/comptech/stock-news/venv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/Desktop/comptech/stock-news/venv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Volume Intensity'

# %%
important_news = get_important_news(important_days[0], ['Microsoft company', 'Bill Gates'], 5)
important_news
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-175-a2fd49b44c9d> in <module>
# ----> 1 important_news = get_important_news(important_days[0], ['Microsoft company', 'Bill Gates'], 5)
#       2 important_news
#
# NameError: name 'important_days' is not defined

# %%
db = connect_to_mongodb()
keywords = pd.DataFrame.from_dict(db['KEYWORDS'].find())
list(keywords['Keywords'])[0]
# Out:
# ['3 Mmm Company Limited',
#  '3M Japan Ltd',
#  'MMM Healthcare, LLC',
#  'MMM Münchener Medizin Mechanik GmbH',
#  'MMM Group Limited',
#  'Morgan–McClure Motorsports',
#  'Zya, Inc.']

# %%
model_dirs
# Out:
# ['model_1_60_7', 'model_1_90_15', 'model_1_30_4']

# %%
import string 
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def clean_column(column):
    s = "".join(e for e in column if e.isalnum() or e == " ")
    return s.strip().strip("_").replace('_', ' ').lower()

def clean_columns(columns):
    res = []
    for column in columns:
        res += [clean_column(column)]
        
    return res

# %%
def process_news(news):
    res = []
    for k, vs in news.items():
        for v in vs:
            res += [(k, v)]
    return res

# %%
clean_columns(['BIO COMPANY GmbH', 'Nissan', 'Hewlett-Packard', 'Facebook', 'Takeda Pharmaceutical Company', 'Cargill', 'Ericsson', 'Netflix', 'Namco', 'Donald Trump'])
# Out:
# ['bio company gmbh',
#  'nissan',
#  'hewlettpackard',
#  'facebook',
#  'takeda pharmaceutical company',
#  'cargill',
#  'ericsson',
#  'netflix',
#  'namco',
#  'donald trump']

# %%
import random

# %%
def level_generator(model_dirs):

    pattern = re.compile('model_(\d+)_(\d+)_(\d+)')
    d = defaultdict(list)
    for item in model_dirs:
        i, db, df = pattern.match(item).groups()
        d[(db, df)] += [item]

    db = connect_to_mongodb()
    keywords = pd.DataFrame.from_dict(db['KEYWORDS'].find())
    #tickets = list(keywords['Ticker'])[0:10]
    #keywords = list(keywords['Keywords'])[0:10]

    MODEL_DIR = str(Path('../data/models/'))
    
    res = []
    for key in d.keys():
        db_model = db[f"MODEL_{key[0]}_{key[1]}"]
        db_model.drop()
        
        counter = 0
        for model in d[key]:
            cat_features = Path(MODEL_DIR + '/' + model + '/cat_features.txt').read_text().split()
            test_df = pd.read_csv(MODEL_DIR + '/' + model + '/test_data.csv',
                               nrows=None)
            
            for i, idx in enumerate(random.sample(range(0, len(test_df.Ticker.unique())), len(test_df.Ticker.unique()))):
                try:
                    if counter == 20:
                        break

                    t = test_df[test_df.Ticker == test_df.Ticker.unique()[idx]]
                    print('Ticker:', test_df.Ticker.unique()[idx])
                    idx_ = random.randint(a=0, b=t.shape[0])
                    test = t.iloc[idx_].to_frame().T

                    date = test['datetime.1'].values[0]
                    days_back = key[0]
                    target = test['target'].values[0]
                    test = test.drop(['datetime.1', 'target'], axis=1)
                    delta = timedelta(days=int(days_back))
                    date_datetime = datetime.strptime(date, "%Y-%m-%d")
                    start_date = date_datetime - delta
                    start_date = start_date.strftime("%Y-%m-%d")

                    model_predict = predict_for_model(MODEL_DIR + '/' + model + '/model.cbm', test, cat_features)
                    keywords_ = list(keywords['Keywords'][keywords['Ticker']==test['Ticker'].values[0]])[0]

                    keywords_ = clean_columns(keywords_)[:4]


                    yfinance_df = get_data_yfinance(quotation=test['Ticker'].values[0],
                                                       start_date=start_date,
                                                       end_date=date)

                    
                    f = set_filters(start_date, days_back, keywords_)
                    gd = GdeltDoc()
                    articles = gd.article_search(f)

                    volumes = gd.timeline_search("timelinevol", f)
                    tones = gd.timeline_search("timelinetone", f)
                    important_days = get_important_days(volumes, 3)
                    news = {}
                    for day in important_days:
                        news[day] = get_important_news(articles, day, keywords_, number_of_news=2)
            #return prices, tones, volumes, news, date, days_back, model_predict, target  news, days_back, model_predict, target

        #             return prices, tones, volumes, news, date, days_back, model_predict, target
        
                    tones['prices'] = pd.Series(yfinance_df['Close'].values)
                    tones = tones.fillna(method="ffill")
                
        
                    d_ = {}
                    d_['prices'] = list(map(float, tones.prices.values))
                    d_['Ticker'] = test_df.Ticker.unique()[idx]
                    d_['tones'] = list(map(float, tones['Average Tone'].values))
                    d_['volumes'] = list(map(float, 100*volumes['Volume Intensity'].values))
                    d_['news'] = process_news(news)
                    d_['date'] = str(date)
                    d_['model_predict'] = int(model_predict[0])
                    d_['days_back'] = int(days_back)
                    d_['target'] = int(target)
                    d_['level_id'] = counter

                    db_model.insert_many([d_])
                    counter += 1
                except Exception as e:
                    print(e)
    #             df = pd.DataFrame()
    #             df['tones'] = list(tones['Average Tone'])
    #             df['volumes'] = list(volumes['Volume Intensity'])
    #             df['date'] = date
    #             model_predict[0]
    #             process_news(news)

# %%
model_dirs = [dir_ for dir_ in listdir(MODEL_DIR) if isdir(join(MODEL_DIR, dir_)) and dir_.startswith('model')]

# %%
model_dirs
# Out:
# ['model_1_60_7', 'model_1_90_15', 'model_1_30_4']

# %%
level_generator(model_dirs)
# Out:
# Ticker: SJM
# [*********************100%***********************]  1 of 1 completed
# Ticker: HBAN
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190907000000&enddatetime=20191106000000&maxrecords=250&mode=artlist&format=json
# ("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190907000000&enddatetime=20191106000000&maxrecords=250
# b"Parentheses may only be used around OR'd statements.\n"
# Expecting value: line 1 column 1 (char 0)
# Ticker: CMS
# [*********************100%***********************]  1 of 1 completed
# Ticker: CAH
# [*********************100%***********************]  1 of 1 completed
# Ticker: APH
# [*********************100%***********************]  1 of 1 completed
# Ticker: HLT
# [*********************100%***********************]  1 of 1 completed
# Ticker: AOS
# [*********************100%***********************]  1 of 1 completed
# Ticker: GPS
# [*********************100%***********************]  1 of 1 completed
# Ticker: ANET
# [*********************100%***********************]  1 of 1 completed
# Ticker: AWK
# [*********************100%***********************]  1 of 1 completed
# Ticker: CTXS
# [*********************100%***********************]  1 of 1 completed
# Ticker: HAS
# [*********************100%***********************]  1 of 1 completed
# Ticker: FRC
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMB
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190919000000&enddatetime=20191118000000&maxrecords=250&mode=artlist&format=json
# ("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190919000000&enddatetime=20191118000000&maxrecords=250
# b'Your query was too short or too long.\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: JPM
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190905000000&enddatetime=20191104000000&maxrecords=250&mode=artlist&format=json
# ("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190905000000&enddatetime=20191104000000&maxrecords=250
# b'Your query contained a phrase search that was too short or too long: sv jpm core mortgage division an investment division of talcott resolution life insurance company\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: KIM
# [*********************100%***********************]  1 of 1 completed
# Ticker: APD
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: EOG
# [*********************100%***********************]  1 of 1 completed
# Ticker: ACN
# [*********************100%***********************]  1 of 1 completed
# Ticker: DE
# [*********************100%***********************]  1 of 1 completed
# Ticker: SCHW
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: DVA
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTV
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETR
# [*********************100%***********************]  1 of 1 completed
# Ticker: BIO
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAL
# [*********************100%***********************]  1 of 1 completed
# Ticker: GPS
# [*********************100%***********************]  1 of 1 completed
# Ticker: SCHW
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: CMS
# [*********************100%***********************]  1 of 1 completed
# Ticker: DE
# [*********************100%***********************]  1 of 1 completed
# Ticker: ANET
# [*********************100%***********************]  1 of 1 completed
# Ticker: HAS
# [*********************100%***********************]  1 of 1 completed
# Ticker: SJM
# [*********************100%***********************]  1 of 1 completed
# Ticker: CTXS
# [*********************100%***********************]  1 of 1 completed
# Ticker: JPM
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190810000000&enddatetime=20191108000000&maxrecords=250&mode=artlist&format=json
# ("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190810000000&enddatetime=20191108000000&maxrecords=250
# b'Your query contained a phrase search that was too short or too long: sv jpm core mortgage division an investment division of talcott resolution life insurance company\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: AOS
# [*********************100%***********************]  1 of 1 completed
# Ticker: APH
# [*********************100%***********************]  1 of 1 completed
# Ticker: ACN
# [*********************100%***********************]  1 of 1 completed
# Ticker: CAH
# [*********************100%***********************]  1 of 1 completed
# Ticker: EOG
# [*********************100%***********************]  1 of 1 completed
# Ticker: HLT
# [*********************100%***********************]  1 of 1 completed
# Ticker: AWK
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETR
# [*********************100%***********************]  1 of 1 completed
# Ticker: HBAN
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190725000000&enddatetime=20191023000000&maxrecords=250&mode=artlist&format=json
# ("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190725000000&enddatetime=20191023000000&maxrecords=250
# b"Parentheses may only be used around OR'd statements.\n"
# Expecting value: line 1 column 1 (char 0)
# Ticker: BIO
# [*********************100%***********************]  1 of 1 completed
# Ticker: APD
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: FRC
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMB
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190905000000&enddatetime=20191204000000&maxrecords=250&mode=artlist&format=json
# ("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20190905000000&enddatetime=20191204000000&maxrecords=250
# b'Your query was too short or too long.\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: DVA
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTV
# [*********************100%***********************]  1 of 1 completed
# Ticker: CAH
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: SJM
# [*********************100%***********************]  1 of 1 completed
# Ticker: HAS
# [*********************100%***********************]  1 of 1 completed
# Ticker: DE
# [*********************100%***********************]  1 of 1 completed
# Ticker: FTV
# [*********************100%***********************]  1 of 1 completed
# Ticker: FRC
# [*********************100%***********************]  1 of 1 completed
# Ticker: KMB
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191020000000&enddatetime=20191119000000&maxrecords=250&mode=artlist&format=json
# ("kmb design company limited" OR "kmb utilities company" OR "kmb international company limited" OR "zao banca intesa closed jointstock company prior to merger with kmbbank")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191020000000&enddatetime=20191119000000&maxrecords=250
# b'Your query was too short or too long.\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: ACN
# [*********************100%***********************]  1 of 1 completed
# Ticker: CMS
# [*********************100%***********************]  1 of 1 completed
# Ticker: ANET
# [*********************100%***********************]  1 of 1 completed
# Ticker: CTXS
# [*********************100%***********************]  1 of 1 completed
# Ticker: JPM
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191023000000&enddatetime=20191122000000&maxrecords=250&mode=artlist&format=json
# ("sv jpm core mortgage division an investment division of talcott resolution life insurance company" OR delfi OR "j p m capital finance limited" OR kwikboost)domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191023000000&enddatetime=20191122000000&maxrecords=250
# b'Your query contained a phrase search that was too short or too long: sv jpm core mortgage division an investment division of talcott resolution life insurance company\n'
# Expecting value: line 1 column 1 (char 0)
# Ticker: BIO
# [*********************100%***********************]  1 of 1 completed
# Ticker: AOS
# [*********************100%***********************]  1 of 1 completed
# Ticker: KIM
# [*********************100%***********************]  1 of 1 completed
# Ticker: HLT
# [*********************100%***********************]  1 of 1 completed
# Ticker: ETR
# [*********************100%***********************]  1 of 1 completed
# Ticker: DVA
# [*********************100%***********************]  1 of 1 completed
# Ticker: EOG
# [*********************100%***********************]  1 of 1 completed
# Ticker: APD
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: HBAN
# [*********************100%***********************]  1 of 1 completed
# https://api.gdeltproject.org/api/v2/doc/doc?query=("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191007000000&enddatetime=20191106000000&maxrecords=250&mode=artlist&format=json
# ("halo business angel network")domain:finance.yahoo.com(sourcecountry:UK OR sourcecountry:US)theme:ECON_STOCKMARKET&startdatetime=20191007000000&enddatetime=20191106000000&maxrecords=250
# b"Parentheses may only be used around OR'd statements.\n"
# Expecting value: line 1 column 1 (char 0)
# Ticker: APH
# [*********************100%***********************]  1 of 1 completed
# Ticker: SCHW
# [*********************100%***********************]  1 of 1 completed
# 'articles'
# Ticker: GPS
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAL
# [*********************100%***********************]  1 of 1 completed
# Ticker: AWK
# [*********************100%***********************]  1 of 1 completed

# %%
test = pd.read_csv(MODEL_DIR + '/' + model + '/test_data.csv',
                               nrows=1)
test['Ticker'][0]
# Out:
# 'ACN'

# %%
list(keywords['Keywords'][keywords['Ticker']=='ACN'])[0]
# Out:
# ['Michael Hill Jeweller',
#  'Dymocks Booksellers',
#  'Alliance Airlines',
#  'NBN Co',
#  'Muzak',
#  "Foster's Group",
#  'Jewelry Television',
#  'Qube Holdings']

# %%
# Search for articles matching the filters
articles = gd.article_search(f)

# %%
articles
# Out:
#                            domain language          seendate  \
# 0                timesnownews.com  English  20190921T130000Z
# 4                     netflix.com  English  20190921T153000Z
# 5               indianexpress.com  English  20190921T134500Z
# 11                  nairaland.com  English  20190921T111500Z
# 12                    decider.com  English  20190921T013000Z
# 13                 boingboing.net  English  20190921T161500Z
# 15                  comicbook.com  English  20190921T000000Z
# 19                         her.ie  English  20190921T090000Z
# 21                 popculture.com  English  20190921T143000Z
# 23                  indiatoday.in  English  20190921T144500Z
# 29                        pbs.org  English  20190921T021500Z
# 33                 boingboing.net  English  20190921T161500Z
# 36              palmbeachpost.com  English  20190921T001500Z
# 37         lifestyle.inquirer.net  English  20190921T221500Z
# 38                    reuters.com  English  20190921T074500Z
# 39               vancouversun.com  English  20190921T101500Z
# 41            businessinsider.com  English  20190921T003000Z
# 42                 news.trust.org  English  20190921T081500Z
# 43                 news.trust.org  English  20190921T093000Z
# 44                        fool.ca  English  20190921T124500Z
# 45                        fool.ca  English  20190921T164500Z
# 48                theguardian.com  English  20190921T143000Z
# 50                    940wfaw.com  English  20190921T014500Z
# 51         abcnewsradioonline.com  English  20190921T014500Z
# 52                  wondradio.com  English  20190921T033000Z
# 53                     hitsfm.net  English  20190921T030000Z
# 54                       ksyl.com  English  20190921T030000Z
# 55                       wkjc.com  English  20190921T034500Z
# 56                       wadk.com  English  20190921T043000Z
# 57           princetonnewsnow.com  English  20190921T044500Z
# ..                            ...      ...               ...
# 59                     mix1005.fm  English  20190921T093000Z
# 60                       wfin.com  English  20190921T053000Z
# 61                        kbtt.fm  English  20190921T074500Z
# 62                1049thebeat.com  English  20190921T071500Z
# 64                    850wftl.com  English  20190921T010000Z
# 68         supplychaindigital.com  English  20190921T133000Z
# 72                  daily-sun.com  English  20190921T033000Z
# 73                      slate.com  English  20190921T101500Z
# 74                  economist.com  English  20190921T014500Z
# 75                 selfgrowth.com  English  20190921T121500Z
# 76           theeastafrican.co.ke  English  20190921T051500Z
# 80                  theage.com.au  English  20190921T170000Z
# 81                   dnaindia.com  English  20190921T020000Z
# 82              sunnewsonline.com  English  20190921T033000Z
# 83                    wionews.com  English  20190921T101500Z
# 84                 eurekalert.org  English  20190921T160000Z
# 85             washingtonpost.com  English  20190921T103000Z
# 86         beaumontenterprise.com  English  20190921T164500Z
# 87                    nytimes.com  English  20190921T131500Z
# 88                     forbes.com  English  20190921T160000Z
# 93         ezorigin.csmonitor.com  English  20190921T004500Z
# 96   slinkingtowardretirement.com  English  20190921T121500Z
# 97                       cnbc.com  English  20190921T133000Z
# 98                       wsau.com  English  20190921T033000Z
# 99             bangladeshinfo.com  English  20190921T091500Z
# 100              kashmirtimes.com  English  20190921T110000Z
# 101               kashmirtimes.in  English  20190921T121500Z
# 102                  enherald.com  English  20190921T124500Z
# 103        newafricanmagazine.com  English  20190921T234500Z
# 104                 chronline.com  English  20190921T011500Z
#
#                                            socialimage   sourcecountry  \
# 0    https://imgk.timesnownews.com/story/1569068177...           India
# 4    https://occ-0-2794-2219.1.nflxso.net/dnm/api/v...   United States
# 5    https://images.indianexpress.com/2019/09/bill-...           India
# 11                                                             Nigeria
# 12   https://nypdecider.files.wordpress.com/2019/09...   United States
# 13                                                       United States
# 15   https://media.comicbook.com/2019/08/netflix-co...   United States
# 19                                                             Ireland
# 21                                                       United States
# 23   https://akm-img-a-in.tosshub.com/indiatoday/im...           India
# 29   https://d3i6fh83elv35t.cloudfront.net/static/2...   United States
# 33                                                       United States
# 36   https://www.palmbeachpost.com/storyimage/LK/20...   United States
# 37   https://lifestyle.inquirer.net/files/2019/09/1...     Philippines
# 38   https://s4.reutersmedia.net/resources_v2/image...   United States
# 39                                                              Canada
# 41   https://amp.businessinsider.com/images/5d84d84...   United States
# 42   https://d2sh4fq2xsdeg9.cloudfront.net/contentA...   United States
# 43   https://d2sh4fq2xsdeg9.cloudfront.net/contentA...   United States
# 44   https://yw553ftvhw1iqegz29fycoyw-wpengine.netd...          Canada
# 45   https://yw553ftvhw1iqegz29fycoyw-wpengine.netd...          Canada
# 48   https://i.guim.co.uk/img/media/57da71c62ea64a5...  United Kingdom
# 50                                                       United States
# 51   http://abcnewsradioonline.com/storage/abcnewsr...   United States
# 52   http://abcnewsradioonline.com/storage/news-ima...   United States
# 53   http://abcnewsradioonline.com/storage/news-ima...   United States
# 54   http://abcnewsradioonline.com/storage/news-ima...   United States
# 55   http://abcnewsradioonline.com/storage/news-ima...   United States
# 56   http://abcnewsradioonline.com/storage/news-ima...   United States
# 57   http://abcnewsradioonline.com/storage/news-ima...
# ..                                                 ...             ...
# 59   https://www.alphamediahub.com/wp-content/uploa...   United States
# 60   https://wfin.com/wp-content/uploads/2019/09/iS...   United States
# 61   https://www.alphamediahub.com/wp-content/uploa...   United States
# 62   https://www.alphamediahub.com/wp-content/uploa...   United States
# 64   https://www.850wftl.com/wp-content/uploads/201...   United States
# 68   http://www.supplychaindigital.com/sites/defaul...  United Kingdom
# 72   https://www.daily-sun.com/assets/news_images/2...      Bangladesh
# 73   https://compote.slate.com/images/fa11450f-9634...   United States
# 74   https://www.economist.com/sites/default/files/...   United States
# 75                                                           Sri Lanka
# 76   https://www.theeastafrican.co.ke/image/view/-/...           Kenya
# 80   https://static.ffx.io/images/$zoom_1%2C$multip...       Australia
# 81   https://cdn.dnaindia.com/sites/default/files/s...           India
# 82   https://sunnewsonline.com/wp-content/uploads/2...         Nigeria
# 83   https://cdn.wionews.com/sites/default/files/st...           India
# 84   https://eurekalert.org/multimedia/pub/web/2119...   United States
# 85   https://www.washingtonpost.com/resizer/Im-S5UI...   United States
# 86   https://s.hdnux.com/photos/01/05/62/50/1829532...   United States
# 87   https://static01.nyt.com/images/2019/09/23/mul...   United States
# 88   https://thumbor.forbes.com/thumbor/600x315/htt...   United States
# 93                                                       United States
# 96   http://slinkingtowardretirement.com/wp-content...   United States
# 97   https://image.cnbcfm.com/api/v1/image/10359715...   United States
# 98                                                       United States
# 99   https://www.bangladeshinfo.com/storage/images/...      Bangladesh
# 100                                                              India
# 101                                                              India
# 102
# 103  https://newafricanmagazine.com/wordpress/wp-co...         Nigeria
# 104  https://bloximages.chicago2.vip.townnews.com/c...   United States
#
#                                                  title  \
# 0    Surprising ! Bill Gates net worth : When he re...
# 4    Inside Bill Brain : Decoding Bill Gates | Netf...
# 5    The simple strategy fueling the rise of Bill G...
# 11   Bill Gates Call For More Funding For Primary H...
# 12     Inside Bill Brain : Decoding Bill Gate Netfl...
# 13                      brandeis revival / Boing Boing
# 15        Everything Releasing On Netflix This Weekend
# 19   5 new additions to Netflix which are worth che...
# 21           Everything Coming to Netflix This Weekend
# 23     I took 15 Economics classes over 4 years in ...
# 29   Why transitioning to only renewable energy wil...
# 33   Bill Gates : if we break up Big Tech , well ju...
# 36   Lake Worth Beach wants to harness the Gulf Str...
# 37   The responsibility that comes with material bl...
# 38   Funding injection needed to stop poor farmer c...
# 39   Funding injection needed to stop poor farmer c...
# 41   MIT campus is in turmoil over its connection t...
# 42   INTERVIEW - Funding injection needed to stop p...
# 43   INTERVIEW - Funding injection needed to stop p...
# 44      An Easy Way to Get TFSA Monthly Income of $292
# 45   Should Telecom Stocks like Bell ( USA ) Invest...
# 48   Vaclav Smil :  Growth must end . Our economist...
# 50   Avocados with longer - lasting technology are ...
# 51   Avocados with longer - lasting technology are ...
# 52                                 ABC Business - WOND
# 53                                  Business - HITS FM
# 54                                Business - KSYL - AM
# 55              Business - Carroll Broadcasting Inc .
# 56                   Business News - 1540 WADK Newport
# 57            ABC - Business News - Princeton News Now
# ..                                                 ...
# 59   Avocados with longer - lasting technology are ...
# 60   Avocados with longer - lasting technology are ...
# 61   Avocados with longer - lasting technology are ...
# 62   Avocados with longer - lasting technology are ...
# 64   Avocados with longer - lasting technology are ...
# 68       Largest Sustainable Supply Chains : Microsoft
# 72   PM reaches Abu Dhabi en route to New York to a...
# 73    Jimmy Carter wanted us to stop climate change .
# 74   Climate capitalists have serious money in clim...
# 75   Why Makes Content Marketing the Driving Force ...
# 76   Scientists release sterile mosquitoes in Burki...
# 80     The serious problems are swept under the carpet
# 81            United States Chants  Howdy Modi  Mantra
# 82   Why it was difficult eradicating polio in Nige...
# 83            United States Chants  Howdy Modi  Mantra
# 84   Malawi study confirms lasting impact of life -...
# 85   What happening in Kashmir ? - The Washington Post
# 86   Producer Brian Grazer traces his success in  F...
# 87   To Feed a Hot Planet , Theyre Making More Effi...
# 88   From STEM Researcher To Startup Co - founder –...
# 93   Melinda Gates : What she learned after $50 bil...
# 96   Modi visit to US : Trump appearance signals im...
# 97    Bill Gates : 13 best TED talks you need to watch
# 98   Perils of gender and geography hamper global d...
# 99                                Bangladeshinfo . com
# 100  Modi faces Houston federal lawsuit for alleged...
# 101  Modi faces Houston federal lawsuit for alleged...
# 102  Microsoft ( MSFT ) Market Valuation Rose While...
# 103  UN General Assembly Special Edition : Squaring...
# 104  Seattle Looks to Churches for Help With Tiny H...
#
#                                                    url  \
# 0    https://www.timesnownews.com/business-economy/...
# 4    https://www.netflix.com/title/80184771?s=i&trk...
# 5    https://indianexpress.com/article/world/the-si...
# 11   https://www.nairaland.com/5429149/bill-gates-c...
# 12   https://decider.com/2019/09/20/inside-bills-br...
# 13         https://boingboing.net/tag/brandeis-revival
# 15   https://comicbook.com/movies/2019/09/20/everyt...
# 19   https://www.her.ie/entertainment/5-new-additio...
# 21   https://popculture.com/streaming/2019/09/20/ev...
# 23   https://www.indiatoday.in/education-today/news...
# 29   https://www.pbs.org/newshour/show/why-transiti...
# 33   https://boingboing.net/2019/09/21/deposition-t...
# 36   https://www.palmbeachpost.com/news/20190920/la...
# 37   https://lifestyle.inquirer.net/346327/the-resp...
# 38   https://www.reuters.com/article/us-climate-cha...
# 39   https://vancouversun.com/pmn/entertainment-pmn...
# 41   https://www.businessinsider.com/mits-campus-pr...
# 42     http://news.trust.org/item/20190921063507-fy5mq
# 43    http://news.trust.org/item/20190921063507-fy5mq/
# 44   https://www.fool.ca/2019/09/21/an-easy-way-to-...
# 45   https://www.fool.ca/2019/09/21/should-telecom-...
# 48   https://www.theguardian.com/books/2019/sep/21/...
# 50   http://www.940wfaw.com/news/avocados-with-long...
# 51   http://abcnewsradioonline.com/business-news/av...
# 52   http://wondradio.com/abc-business/dfecb272c591...
# 53   https://hitsfm.net/abc-business-news/dfecb272c...
# 54   https://ksyl.com/business/dfecb272c59131959d87...
# 55   https://wkjc.com/business-news/dfecb272c591319...
# 56   https://wadk.com/business-news/dfecb272c591319...
# 57   https://princetonnewsnow.com/abc-business-news...
# ..                                                 ...
# 59   https://www.mix1005.fm/syndicated-article/?id=...
# 60   https://wfin.com/abc-business-news/avocados-wi...
# 61   https://www.kbtt.fm/syndicated-article/?id=106...
# 62   https://www.1049thebeat.com/syndicated-article...
# 64   https://www.850wftl.com/avocados-with-longer-l...
# 68   https://www.supplychaindigital.com/supply-chai...
# 72   https://www.daily-sun.com/post/425191/2019/09/...
# 73   https://slate.com/technology/2019/09/jimmy-car...
# 74   https://www.economist.com/business/2019/09/19/...
# 75   https://www.selfgrowth.com/articles/why-makes-...
# 76   https://www.theeastafrican.co.ke/scienceandhea...
# 80   https://www.theage.com.au/national/drug-testin...
# 81   https://www.dnaindia.com/analysis/column-unite...
# 82   https://www.sunnewsonline.com/why-it-was-diffi...
# 83   https://www.wionews.com/opinions/united-states...
# 84   https://eurekalert.org/pub_releases/2019-09/ru...
# 85   https://www.washingtonpost.com/politics/2019/0...
# 86   https://www.beaumontenterprise.com/entertainme...
# 87   https://www.nytimes.com/2019/09/21/climate/aus...
# 88   https://www.forbes.com/sites/johngreathouse/20...
# 93   https://ezorigin.csmonitor.com/World/Making-a-...
# 96       http://slinkingtowardretirement.com/?p=313464
# 97   https://www.cnbc.com/2019/09/21/bill-gates-13-...
# 98   https://wsau.com/news/articles/2019/sep/17/per...
# 99   https://www.bangladeshinfo.com/article/4372/pm...
# 100   http://www.kashmirtimes.com/newsdet.aspx?q=94787
# 101    http://www.kashmirtimes.in/newsdet.aspx?q=94787
# 102  https://enherald.com/microsoft-msft-market-val...
# 103              https://newafricanmagazine.com/19793/
# 104  http://www.chronline.com/northwest_regional_ne...
#
#                                             url_mobile
# 0    https://www.timesnownews.com/amp/business-econ...
# 4
# 5    https://indianexpress.com/article/world/the-si...
# 11
# 12   https://decider.com/2019/09/20/inside-bills-br...
# 13
# 15   https://comicbook.com/movies/amp/2019/09/20/ev...
# 19   https://www.her.ie/amp/entertainment/5-new-add...
# 21   https://popculture.com/streaming/amp/2019/09/2...
# 23   https://www.indiatoday.in/amp/education-today/...
# 29   https://www.pbs.org/newshour/amp/show/why-tran...
# 33   https://boingboing.net/2019/09/21/deposition-t...
# 36   https://www.palmbeachpost.com/news/20190920/la...
# 37   https://lifestyle.inquirer.net/346327/the-resp...
# 38   https://mobile.reuters.com/article/amp/idUSKBN...
# 39   https://vancouversun.com/pmn/entertainment-pmn...
# 41   https://amp.businessinsider.com/mits-campus-pr...
# 42   http://mercury.postlight.com/amp?url=http://ne...
# 43   http://mercury.postlight.com/amp?url=http://ne...
# 44
# 45
# 48   https://amp.theguardian.com/books/2019/sep/21/...
# 50
# 51
# 52
# 53
# 54
# 55
# 56
# 57
# ..                                                 ...
# 59
# 60
# 61
# 62
# 64
# 68   https://www.supplychaindigital.com/supply-chai...
# 72
# 73   https://slate.com/technology/2019/09/jimmy-car...
# 74   https://amp.economist.com/business/2019/09/19/...
# 75
# 76   https://www.theeastafrican.co.ke/scienceandhea...
# 80   https://amp.theage.com.au/national/drug-testin...
# 81   https://www.dnaindia.com/analysis/column-unite...
# 82   https://www.sunnewsonline.com/why-it-was-diffi...
# 83   https://www.wionews.com/opinions/united-states...
# 84
# 85   https://www.washingtonpost.com/politics/2019/0...
# 86   https://www.beaumontenterprise.com/entertainme...
# 87   https://www.nytimes.com/2019/09/21/climate/aus...
# 88   https://www.forbes.com/sites/johngreathouse/20...
# 93   https://ezorigin.csmonitor.com/layout/set/amph...
# 96
# 97   https://www.cnbc.com/amp/2019/09/21/bill-gates...
# 98
# 99
# 100
# 101
# 102
# 103
# 104
#
# [61 rows x 8 columns]

# %%
articles = articles[articles['language'] == 'English']

# %%
list(articles['title'])[3]
# Out:
# 'Bill Gates Call For More Funding For Primary Health Care In Nigeria - Health'

# %%
articles[['url', 'title']]['title'].values
# Out:
# array(['Surprising ! Bill Gates net worth : When he resigned as Microsoft CEO',
#        'Inside Bill Brain : Decoding Bill Gates | Netflix Official Site',
#        'The simple strategy fueling the rise of Bill Gates fortune | World News , The Indian Express',
#        'Bill Gates Call For More Funding For Primary Health Care In Nigeria - Health',
#        '  Inside Bill Brain : Decoding Bill Gate Netflix Review : Stream It Or Skip It ? ',
#        'brandeis revival / Boing Boing',
#        'Everything Releasing On Netflix This Weekend',
#        '5 new additions to Netflix which are worth checking out this weekend',
#        'Everything Coming to Netflix This Weekend',
#        '  I took 15 Economics classes over 4 years in my BA education : Wipro Chairman Rishad Premji',
#        'Why transitioning to only renewable energy will be difficult for the U . S . ',
#        'Bill Gates : if we break up Big Tech , well just have more bad companies',
#        'Lake Worth Beach wants to harness the Gulf Stream power - News - The Palm Beach Post',
#        'The responsibility that comes with material blessings',
#        'Funding injection needed to stop poor farmer climate pain spreading',
#        'Funding injection needed to stop poor farmer climate pain spreading',
#        'MIT campus is in turmoil over its connection to Jeffrey Epstein',
#        'INTERVIEW - Funding injection needed to stop poor farmer ... ',
#        'INTERVIEW - Funding injection needed to stop poor farmer ... ',
#        'An Easy Way to Get TFSA Monthly Income of $292',
#        'Should Telecom Stocks like Bell ( USA ) Invest in Content ? ',
#        'Vaclav Smil :  Growth must end . Our economist friends dont seem to realise that  | Books',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the\xa0country - Business News',
#        'ABC Business - WOND', 'Business - HITS FM',
#        'Business - KSYL - AM', 'Business - Carroll Broadcasting Inc . ',
#        'Business News - 1540 WADK Newport',
#        'ABC - Business News - Princeton News Now',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Avocados with longer - lasting technology are finally in stores across the country',
#        'Largest Sustainable Supply Chains : Microsoft',
#        'PM reaches Abu Dhabi en route to New York to attend 74th UNGA',
#        'Jimmy Carter wanted us to stop climate change . ',
#        'Climate capitalists have serious money in climate - friendly investments',
#        'Why Makes Content Marketing the Driving Force Behind Online Trades in 2019 ? ',
#        'Scientists release sterile mosquitoes in Burkina to fight',
#        'The serious problems are swept under the carpet',
#        'United States Chants  Howdy Modi  Mantra',
#        'Why it was difficult eradicating polio in Nigeria – Siddique , Unicef Polio Chief – The Sun Nigeria',
#        'United States Chants  Howdy Modi  Mantra',
#        'Malawi study confirms lasting impact of life - saving technology',
#        'What happening in Kashmir ? - The Washington Post',
#        'Producer Brian Grazer traces his success in  Face to Face  ',
#        'To Feed a Hot Planet , Theyre Making More Efficient Plants',
#        'From STEM Researcher To Startup Co - founder – Jenny Du Venture Is Revolutionizing A $9 Trillion Market',
#        'Melinda Gates : What she learned after $50 billion of giving',
#        'Modi visit to US : Trump appearance signals importance of India – BBC News',
#        'Bill Gates : 13 best TED talks you need to watch',
#        'Perils of gender and geography hamper global development , report finds | News',
#        'Bangladeshinfo . com',
#        'Modi faces Houston federal lawsuit for alleged HR abuses in Kashmir',
#        'Modi faces Houston federal lawsuit for alleged HR abuses in Kashmir',
#        'Microsoft ( MSFT ) Market Valuation Rose While Ironwood Investment Counsel Has Decreased Its Holding ; As Chevron ( CVX ) Stock Value Rose , Hollencrest Securities Boosted Its Position by $473 , 928',
#        'UN General Assembly Special Edition : Squaring up to inequality in Africa',
#        'Seattle Looks to Churches for Help With Tiny House Villages but Continued Tensions Could Complicate Efforts'],
#       dtype=object)

# %%
def get_importtant_news(important_days,)
