# %%
from gdeltdoc import GdeltDoc, Filters, near, repeat


f = Filters(
    start_date = "2020-05-01",
    end_date = "2020-05-02",
    num_records = 250,
    keyword = "climate change",
    domain = ["bbc.co.uk", "nytimes.com"],
    country = ["UK", "US"],
    theme = "GENERAL_HEALTH",
    near = near(10, "airline", "carbon"),
    repeat = repeat(5, "planet")
)

# %%
gd = GdeltDoc()

# %%
# Search for articles matching the filters
articles = gd.article_search(f)

# %%
articles.head()
# Out:
#                                                  url  \
# 0       https://www.bbc.co.uk/news/uk-wales-52499099
# 1  https://www.bbc.co.uk/news/uk-northern-ireland...
# 2  https://www.bbc.co.uk/news/uk-wales-politics-5...
# 3       https://www.bbc.co.uk/news/uk-wales-52502427
# 4       https://www.bbc.co.uk/news/uk-wales-52499915
#
#                                           url_mobile  \
# 0   https://www.bbc.co.uk/news/amp/uk-wales-52499099
# 1  https://www.bbc.com/news/amp/uk-northern-irela...
# 2  https://www.bbc.co.uk/news/amp/uk-wales-politi...
# 3   https://www.bbc.co.uk/news/amp/uk-wales-52502427
# 4     https://www.bbc.com/news/amp/uk-wales-52499915
#
#                                                title          seendate  \
# 0  Betsi Cadwaladr : Vascular staff  fear for car...  20200501T171500Z
# 1  Coronavirus : No dash for the lockdown exit , ...  20200501T171500Z
# 2  Coronavirus : Wales has  begun to come over pe...  20200501T171500Z
# 3  Coronavirus : MPs urge chancellor to support s...  20200501T171500Z
# 4  Coronavirus : Machynlleth Comedy Festival plan...  20200501T171500Z
#
#                                          socialimage     domain language  \
# 0  https://ichef.bbci.co.uk/news/1024/branded_new...  bbc.co.uk  English
# 1  https://ichef.bbci.co.uk/news/1024/branded_new...  bbc.co.uk  English
# 2  https://ichef.bbci.co.uk/news/1024/branded_new...  bbc.co.uk  English
# 3  https://ichef.bbci.co.uk/news/1024/branded_new...  bbc.co.uk  English
# 4  https://ichef.bbci.co.uk/news/1024/branded_new...  bbc.co.uk  English
#
#     sourcecountry
# 0  United Kingdom
# 1  United Kingdom
# 2  United Kingdom
# 3  United Kingdom
# 4  United Kingdom

# %%
# Get a timeline of the number of articles matching the filters
timeline = gd.timeline_search("timelinetone", f)

# %%
timeline.head()
# Out:
#                    datetime  Average Tone
# 0 2020-05-01 00:00:00+00:00       -1.3651
# 1 2020-05-01 00:15:00+00:00       -2.5730
# 2 2020-05-01 00:30:00+00:00       -1.4549
# 3 2020-05-01 00:45:00+00:00       -1.4770
# 4 2020-05-01 01:00:00+00:00       -1.0339
